# %% [markdown]
# This is a python 3 Jupyter notebook for the "Array of Things"

# %%
import pandas as pd

# Load the 'Array of things' dataset on Socrata into a DataFrame

AoT_url = "http://data.cityofchicago.org/resource/dbwu-caep.csv"
df = pd.read_csv(AoT_url)

df.shape
# Out:
# (46, 17)

# %%
df.head()
# Out:
#    :@computed_region_43wa_7qmu  :@computed_region_6mkv_f3dw  \
# 0                           40                        22535
# 1                           47                        21202
# 2                           37                        22538
# 3                           36                        14912
# 4                           10                        21194
#
#    :@computed_region_bdys_3d7i  :@computed_region_rpca_8um6  \
# 0                          298                            1
# 1                          505                           25
# 2                          417                           24
# 3                          367                           29
# 4                          374                           40
#
#    :@computed_region_vrxf_vc4k                           category   latitude  \
# 0                           25                  Urban Placemaking  41.912354
# 1                           42  Urban Impact on Climate & Weather  41.741086
# ...

# %%
useful = [7, 14, 15, 12, 6, 17, 16]

ludf = df[df['status'] == 'Live'][['latitude', 'longitude', 'name', 'location_type', 'category', 'notes']]
ludf.head()

# Shifted by one unit (5 - ...) because the count is from 0 here.
# Out:
#      latitude  longitude                  name  \
# 5   41.884579 -87.647359      Randolph-Halsted
# 12  41.831744 -87.675319      Damen and Archer
# 14  41.882391 -87.671675           Warren-Wood
# 19  41.852493 -87.676048      Damen and Cermak
# 41  41.883205 -87.627769  State and Washington
#
#                         location_type                                category  \
# 5                       E-W transects       Urban Impact on Climate & Weather
# 12  Pilsen and Stevensen Transect -AQ  Urban Air Quality and Health Education
# 14                      E-W transects       Urban Impact on Climate & Weather
# 19  Pilsen and Stevensen Transect -AQ  Urban Air Quality and Health Education
# 41  Downtown and Federal Campus (GSA)       Urban Vehicle and Pedestrian Flow
#
#                                                 notes
# 5                                                 NaN
# 12                                        single node
# ...

# %%
ludf.shape
# Out:
# (9, 6)
